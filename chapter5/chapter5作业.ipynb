# %% [markdown]
# # Chapter 5. 函数 II
#
# ## 作业
#
# 本章Part 1迭代器、生成器、函数式编程等都是进阶内容，未必要完全掌握，故仅在后续遇到的时候再次强调，以加深印象。本章的作业主要围绕Part 2。Part 2的目的不仅仅是教会大家模块的安装和使用，还希望大家更进一步，尝试利用Python解决问题。
#
# 本次作业要求大家使用jieba和snownlp完成文本分析的两类经典任务：分词和情感极性分析。迄今为止，本教程还没有涉及相关内容，所以本次作业主要考察运用现有知识和学习新知识的能力。具体的文本处理方法会在后续章节深入讲解。
#
# 本次作业提供了两份待分析文本：
#
# **文本A**:
#
# 记者11月15日从海南省三亚市公安局获悉，一名俄罗斯女子涉嫌在华非法就业，近日被三亚市公安局拘留审查30日。三亚警方15日透露，11月9日，三亚市公安局出入境管理支队民警在工作中发现俄罗斯女子KUPRINAOLGA（中文名欧丽娅）涉嫌在华非法就业，并于当日在三亚湾某餐厅将其查获。经警方调查，欧丽娅于2017年11月3日持“M”贸易签证从深圳皇岗口岸入境，入境后于当日抵达三亚，未按规定取得工作许可和工作类居留证件在中国境内工作，违反了《中华人民共和国出境入境管理法》的相关规定，构成了在华非法就业的事实。目前，欧丽娅因涉嫌在华非法就业被三亚市公安局依法拘留审查30日，案件正在进一步办理中。三亚警方提示，外国人在中国境内工作，应当按照规定取得工作许可和工作类居留证件，不能从事与签证类型不相符的工作，如果违反相关规定，公安机关将按外国人在华非法就业依法进行处理。
#
# **文本B**：
#
# 据香港中评社11月15日报道，台湾方面陆委会委托台“高等政策研究协会”今天（15日）上午举行研讨会，受邀的美国丹佛大学教授赵穗生在回应媒体访问时表示，过去大陆对台政策重点是“防独”，现在日益转向“促统”，虽然对台政策软硬都有，但官方立场仍为和平统一。赵穗生并认为，虽然大陆对台没有统一的时间表，大陆正更积极主动地实现“中国梦”、追求其国家统一的目标，这就暗示了解决台湾问题的时间表，或许2035年经济小康、2050年成为强大国家两个时间点，也就是中国伟大复兴的两步战略，会有要达到阶段性的目标。对于大陆的对台政策，赵穗生称，由于大陆日益强大，大陆对台湾的政策也日益强硬，但当然仍然是软硬都有，软的一面就是和平统一，收买台湾人心，用经济来处理政治，这条路实际还在执行，另一面用武力迫使台湾接受一个中国原则。他又表示，虽然大陆上两种观点同时存在，也各有支持者，但他观察到大陆的官方政策还是和平统一，但和平统一的着眼点上过去放在防止台湾岛内“台独”势力的发展，现在是透过经济政策，因为台湾岛上有一些经济问题，台湾的就业也比较困难，所以大陆用更多的方式、创造很多优惠吸引台湾的商人、年轻人到大陆去，让他们经济上更依存，也更认同大陆。赵穗生认为，虽然大陆对台没有统一的时间表，但时间表存在大陆一般人的心里，而且大陆正更积极主动的实现中国梦、追求其国家统一的目标，这就暗示了解决台湾问题的时间表，或许2035年经济小康、2050年成为强大国家两个时间点，也就是中国伟大复兴的两步战略，会有要达到阶段性的目标。

# %% [markdown]
# ----
# ### task1：分词
#
# 请使用jieba对以上两份文本进行分词处理。
#
# 要求：返回list。如，输入'江州市长江大桥'，输出`['江州市','长江大桥']`。

# %% [markdown]
# ### task2：情感极性
#
# 请使用snownlp计算以上两份文本的情感极性。情感极性介于0到1之间，绝对消极为0，绝对积极为1。

# %% [markdown]
# **提示**：
#
# 1. jieba已经在教程中引导大家安装完毕。snownlp需要自行安装。
# 2. snownlp的项目页面上已经把基本用法写得很清楚了。
